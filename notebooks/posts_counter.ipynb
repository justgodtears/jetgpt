# %%
import json
from pathlib import Path
import pandas as pd

raw_data_dir = Path("../data/raw/")
proccessed_dir = Path("../data/processed/")
goal = 89600000
#
# total = 0
# for file in raw_data_dir.iterdir():
#     with open(file) as f:
#         total += sum(1 for _ in f)
# print(f"Total raw rows:{total}")

total_proc = 0
for file in proccessed_dir.iterdir():
    df = pd.read_parquet(file)
    total_proc += len(df)
print(f"Total processed rows:{total_proc}")
# Out:
# Total processed rows:58953819

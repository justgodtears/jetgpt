# %%
import numpy as np
array = np.load("../data/tokenized/encoded_corpus.npy")
print(array.shape)
print(array.dtype)
print(array[:50])
# Out:
# (1716848321,)
# uint16
# [ 7757    70  8628    17 17808  8412  7470  7310  7683  8191  7307  7409
#     19  9011 18396  7394  8465    19    64  7925    66     3 10553  7814
#  16256  7999  7775 14035  7385  1601 16669  7320  7497  7445  7547  9209
#   1602  7399    46  1598    82  8113  8025 21524     7     3 15727  7320
#   8247  7419]

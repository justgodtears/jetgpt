# %%
import pandas as pd

df1 = pd.read_parquet("../data/processed/processed_data__17-45__09_02_2026.parquet")
df2 = pd.read_parquet("../data/processed/processed_data__17-00__08_31_2026.parquet")
df3 = pd.read_parquet("../data/processed/processed_data__13-30__09_04_2026.parquet")

print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (3285255, 2)
# (2875807, 2)
# (3260891, 2)

# %%
count_www_links = df1["text"].str.contains(r"www\.\S+").sum()
print(count_www_links, df1.shape[0])

count_www_links = df2["text"].str.contains(r"www\.\S+").sum()
print(count_www_links, df2.shape[0])
# Out:
# 96895 3285255
# 106289 2875807

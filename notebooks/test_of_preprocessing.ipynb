# %%
import pandas as pd

df = pd.read_parquet("../data/processed/processed_data__17-00__08_31_2026.parquet")
print(df.shape)
print(df.head())
# Out:
# (2875807, 2)
#                                                 text langs
# 0  but, let's say it all, that Queen Elizabeth ai...  [en]
# 1  yes, certainly. I meant it's a long time to ho...  [en]
# 2  well, good luck with sea drones surface and su...  [en]
# 3  media control in the US. You get the interview...  [en]
# 4                         looping like a centrifuge.  [en]

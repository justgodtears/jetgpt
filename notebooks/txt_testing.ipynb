# %%
import os
print(os.path.getsize("../data/archive/processed_corpus__17-00__08_31_2026.txt"))
# Out:
# 354830281

# %%
with open("../data/archive/processed_corpus__17-00__08_31_2026.txt", encoding="utf-8") as f:
    for i, line in enumerate(f):
        print(line)
        if i >= 5:
            break
# Out:
# but, let's say it all, that Queen Elizabeth aircraft carrier as well. I have no clue what was the strategic thought behind that. looks like a pincushion to me in times of drone swarms.
#
# yes, certainly. I meant it's a long time to hold breath while russia goes ballistic full gas using also NKorean production.
#
# Unfortunately that will mean a lot of suffered destruction, now that russia has discovered the opening.
#
# well, good luck with sea drones surface and submerged. In any case, given the recent budget issues with the UK military, you come to wonder if it was the best choice to get the most efficient military or a lot of imperial nostalgia played in.
#
# media control in the US. You get the interview, but no one is going to air it.
#
# looping like a centrifuge.

# %%
with open("../data/archive/processed_corpus__17-00__08_31_2026.txt", encoding="utf-8") as f:
    lines = f.readlines()
print(len(lines))
# Out:
# 2875807
